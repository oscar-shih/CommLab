# %%
import qiskit
import numpy as np
import math
from qiskit import *
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from math import sqrt, pi

# %% [markdown]
# # Question 1

# %% [markdown]
# Question1-(e)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q,c)
circuit.initialize
# Out:
# <bound method initialize of <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f3de035ae00>>

# %%
circuit.x(q[0])
circuit.draw()
# Out:
#        ┌───┐
#  q194: ┤ X ├
#        └───┘
# c12: 1/═════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
circuit.measure(q, c)
circuit.draw()
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'1': 1024}

# %% [markdown]
# Question1-(f)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q,c)
circuit.initialize
# Out:
# <bound method initialize of <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f3dd6ef8130>>

# %%
circuit.h(q[0]) 
circuit.draw()
# Out:
#          ┌───┐
#  q11653: ┤ H ├
#          └───┘
# c2271: 1/═════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
# circuit.h(q[0])
circuit.measure(q, c)
circuit.draw()
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0': 533, '1': 491}

# %% [markdown]
# Question1-(g)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q,c)
circuit.initialize
# Out:
# <bound method initialize of <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f3de00a9c30>>

# %%
circuit.rx(math.pi/2, q[0])
circuit.draw()
# Out:
#        ┌─────────┐
#  q208: ┤ Rx(π/2) ├
#        └─────────┘
# c14: 1/═══════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# Statevector([0.70710678+0.j        , 0.        -0.70710678j],
#             dims=(2,))

# %% [markdown]
# Question1-(h)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q,c)
circuit.initialize
# Out:
# <bound method initialize of <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f3ddbe33be0>>

# %%
circuit.ry(2*math.asin(sqrt(2/3)), q)
circuit.h(q)
circuit.draw()
# Out:
#        ┌────────────┐┌───┐
#  q211: ┤ Ry(1.9106) ├┤ H ├
#        └────────────┘└───┘
# c15: 1/═══════════════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# Statevector([ 0.98559856+0.00000000e+00j, -0.16910198-2.07090197e-17j],
#             dims=(2,))

# %%
circuit.h(q)
circuit.measure(q, c)
circuit.draw()
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0': 337, '1': 687}

# %% [markdown]
# Bonus

# %% [markdown]
# # Question 2

# %% [markdown]
# Question2-(a)

# %%
q = QuantumRegister(2)
c = ClassicalRegister(2)
circuit = QuantumCircuit(q,c)

# %%
circuit.h(q[0])
circuit.h(q[1])
circuit.draw()
# Out:
#         ┌───┐
# q223_0: ┤ H ├
#         ├───┤
# q223_1: ┤ H ├
#         └───┘
#  c16: 2/═════

# %%
circuit.measure(q, c)
circuit.draw()
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'11': 265, '10': 254, '00': 258, '01': 247}

# %% [markdown]
# Question2-(b)

# %%
circuit = QuantumCircuit(q,c)
circuit.initialize
# Out:
# <bound method initialize of <qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f3ddbc43df0>>

# %%
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.draw()
# Out:
#         ┌───┐
# q223_0: ┤ H ├──■──
#         └───┘┌─┴─┐
# q223_1: ─────┤ X ├
#              └───┘
#  c16: 2/══════════

# %%
circuit.measure(q, c)
circuit.draw()
# Out:
#         ┌───┐     ┌─┐
# q223_0: ┤ H ├──■──┤M├───
#         └───┘┌─┴─┐└╥┘┌─┐
# q223_1: ─────┤ X ├─╫─┤M├
#              └───┘ ║ └╥┘
#  c16: 2/═══════════╩══╩═
#                    0  1

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'11': 505, '00': 519}

# %% [markdown]
# Question2-(c)

# %%
circuit = QuantumCircuit(q,c)

# %%
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.h(q[0])
circuit.h(q[1])
circuit.draw()
# Out:
#         ┌───┐     ┌───┐
# q223_0: ┤ H ├──■──┤ H ├
#         └───┘┌─┴─┐├───┤
# q223_1: ─────┤ X ├┤ H ├
#              └───┘└───┘
#  c16: 2/═══════════════

# %%
circuit.measure(q,c)
circuit.draw()
# Out:
#         ┌───┐     ┌───┐┌─┐
# q223_0: ┤ H ├──■──┤ H ├┤M├───
#         └───┘┌─┴─┐├───┤└╥┘┌─┐
# q223_1: ─────┤ X ├┤ H ├─╫─┤M├
#              └───┘└───┘ ║ └╥┘
#  c16: 2/════════════════╩══╩═
#                         0  1

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'00': 510, '11': 514}

# %% [markdown]
# Question2-(d)

# %%
circuit = QuantumCircuit(q,c)
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.h(q[0])
circuit.h(q[1])
circuit.measure(q,c)
circuit.draw() # |00> + |11>
# Out:
#         ┌───┐     ┌───┐┌─┐
# q223_0: ┤ H ├──■──┤ H ├┤M├───
#         └───┘┌─┴─┐├───┤└╥┘┌─┐
# q223_1: ─────┤ X ├┤ H ├─╫─┤M├
#              └───┘└───┘ ║ └╥┘
#  c16: 2/════════════════╩══╩═
#                         0  1

# %%
circuit = QuantumCircuit(q,c)
circuit.x(q[1])
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.measure(q,c)
circuit.draw() # |01> + |10>
# Out:
#         ┌───┐     ┌─┐
# q223_0: ┤ H ├──■──┤M├───
#         ├───┤┌─┴─┐└╥┘┌─┐
# q223_1: ┤ X ├┤ X ├─╫─┤M├
#         └───┘└───┘ ║ └╥┘
#  c16: 2/═══════════╩══╩═
#                    0  1

# %%
circuit = QuantumCircuit(q,c)
circuit.x(q[0])
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.measure(q,c)
circuit.draw() # |00> - |11>
# Out:
#         ┌───┐┌───┐     ┌─┐
# q223_0: ┤ X ├┤ H ├──■──┤M├───
#         └───┘└───┘┌─┴─┐└╥┘┌─┐
# q223_1: ──────────┤ X ├─╫─┤M├
#                   └───┘ ║ └╥┘
#  c16: 2/════════════════╩══╩═
#                         0  1

# %%
circuit = QuantumCircuit(q,c)
circuit.x(q[0])
circuit.x(q[1])
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.measure(q,c)
circuit.draw() # |01> - |10>
# Out:
#         ┌───┐┌───┐     ┌─┐
# q223_0: ┤ X ├┤ H ├──■──┤M├───
#         ├───┤└───┘┌─┴─┐└╥┘┌─┐
# q223_1: ┤ X ├─────┤ X ├─╫─┤M├
#         └───┘     └───┘ ║ └╥┘
#  c16: 2/════════════════╩══╩═
#                         0  1

# %% [markdown]
# Question2-(e)

# %%
circuit = QuantumCircuit(q,c)

# %%
circuit.u3(math.pi/2, math.pi/3, math.pi/5, q[0])
circuit.u3(math.pi/4, math.pi/2, math.pi/5, q[1])
circuit.swap(q[1], q[0])
circuit.draw()
# Out:
# /tmp/ipykernel_159080/1179856135.py:1: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   circuit.u3(math.pi/2, math.pi/3, math.pi/5, q[0])
# /tmp/ipykernel_159080/1179856135.py:2: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   circuit.u3(math.pi/4, math.pi/2, math.pi/5, q[1])
#         ┌─────────────────┐
# q223_0: ┤ U3(π/2,π/3,π/5) ├─X─
# ...

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# Statevector([ 6.53281482e-01+0.j        ,  1.65693518e-17+0.27059805j,
#               3.26640741e-01+0.56575836j, -2.34344786e-01+0.13529903j],
#             dims=(2, 2))

# %%
circuit = QuantumCircuit(q,c)

# %%
circuit.u3(math.pi/2, math.pi/3, math.pi/5, q[0])
circuit.u3(math.pi/4, math.pi/2, math.pi/5, q[1])
circuit.cx(q[0], q[1])
circuit.cx(q[1], q[0])
circuit.cx(q[0], q[1])
circuit.draw()
# Out:
# /tmp/ipykernel_159080/2224321184.py:1: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   circuit.u3(math.pi/2, math.pi/3, math.pi/5, q[0])
# /tmp/ipykernel_159080/2224321184.py:2: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   circuit.u3(math.pi/4, math.pi/2, math.pi/5, q[1])
#         ┌─────────────────┐     ┌───┐
# q223_0: ┤ U3(π/2,π/3,π/5) ├──■──┤ X ├──■──
# ...

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit, simulator)
result = job.result()
statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# Statevector([ 6.53281482e-01+0.j        ,  1.65693518e-17+0.27059805j,
#               3.26640741e-01+0.56575836j, -2.34344786e-01+0.13529903j],
#             dims=(2, 2))

# %% [markdown]
# # Question 3

# %% [markdown]
# Question3-(a)

# %%
q = QuantumRegister(1)
c = ClassicalRegister(1)
circuit_1 = QuantumCircuit(q,c)
circuit_2 = QuantumCircuit(q,c)

# %%
circuit_1.h(q)
circuit_1.x(q) 
circuit_1.draw()
# Out:
#        ┌───┐┌───┐
#  q250: ┤ H ├┤ X ├
#        └───┘└───┘
# c17: 1/══════════

# %%
circuit_2.h(q)
circuit_2.y(q)
circuit_2.z(q)
circuit_2.draw()
# Out:
#        ┌───┐┌───┐┌───┐
#  q250: ┤ H ├┤ Y ├┤ Z ├
#        └───┘└───┘└───┘
# c17: 1/═══════════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit_1, simulator)
result = job.result()
statevector_1 = result.get_statevector()
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit_2, simulator)
result = job.result()
statevector_2 = result.get_statevector()
print(statevector_1.equiv(statevector_2))
# Out:
# True

# %%
plot_bloch_multivector(statevector_1)

# %%
plot_bloch_multivector(statevector_2)

# %%
circuit_1.measure(q,c)
circuit_2.measure(q,c)

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_1, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'1': 523, '0': 501}

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_2, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'1': 482, '0': 542}

# %% [markdown]
# Question3-(b)

# %%
circuit_1 = QuantumCircuit(q,c)
circuit_2 = QuantumCircuit(q,c)
circuit_1.rx(pi/2, q)
circuit_1.rz(5*pi/8, q) 
circuit_2.ry(pi/2, q)
circuit_2.rz(pi/8, q)

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit_1, simulator)
result = job.result()
statevector_1 = result.get_statevector()
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit_2, simulator)
result = job.result()
statevector_2 = result.get_statevector()
print(statevector_1.equiv(statevector_2))
# Out:
# True

# %%
print(statevector_1)
plot_bloch_multivector(statevector_1)
# Out:
# Statevector([0.39284748-0.5879378j , 0.5879378 -0.39284748j],
#             dims=(2,))

# %%
print(statevector_2)
plot_bloch_multivector(statevector_2)
# Out:
# Statevector([0.69351992-0.13794969j, 0.69351992+0.13794969j],
#             dims=(2,))

# %%
circuit_1.measure(q,c)
circuit_2.measure(q,c)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_1, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0': 514, '1': 510}

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_2, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0': 530, '1': 494}

# %% [markdown]
# Question3-(c)

# %%
circuit_1 = QuantumCircuit(q,c)
circuit_2 = QuantumCircuit(q,c)
circuit_1.x(q)
circuit_1.h(q)
circuit_1.draw()
# Out:
#        ┌───┐┌───┐
#  q250: ┤ X ├┤ H ├
#        └───┘└───┘
# c17: 1/══════════

# %%
circuit_2.h(q)
circuit_2.draw()
# Out:
#        ┌───┐
#  q250: ┤ H ├
#        └───┘
# c17: 1/═════

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit_1, simulator)
result = job.result()
statevector_1 = result.get_statevector()
print(statevector_1)
plot_bloch_multivector(statevector_1)
# Out:
# Statevector([ 0.70710678+0.00000000e+00j, -0.70710678-8.65956056e-17j],
#             dims=(2,))

# %%
simulator = Aer.get_backend('statevector_simulator')
job = execute(circuit_2, simulator)
result = job.result()
statevector_2 = result.get_statevector()
print(statevector_2)
plot_bloch_multivector(statevector_2)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
statevector_1.equiv(statevector_2)
# Out:
# False

# %%
circuit_1.measure(q,c)
circuit_1.draw()
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_1, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0': 499, '1': 525}

# %%
circuit_2.measure(q,c)
circuit_2.draw()
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit_2, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'1': 507, '0': 517}

# %% [markdown]
# # Question 4

# %%
q = QuantumRegister(3)
c = ClassicalRegister(1)

# %%
circuit = QuantumCircuit(q,c)
circuit.rx(pi/2, q[0])
circuit.rx(pi/2, q[1])
circuit.h(q[2])
circuit.cswap(q[2],q[0], q[1])
circuit.h(q[2])
circuit.x(q[2])
circuit.measure(q[2],c)
circuit.draw()
# Out:
#         ┌─────────┐
# q314_0: ┤ Rx(π/2) ├─X──────────────
#         ├─────────┤ │
# q314_1: ┤ Rx(π/2) ├─X──────────────
#         └──┬───┬──┘ │ ┌───┐┌───┐┌─┐
# q314_2: ───┤ H ├────■─┤ H ├┤ X ├┤M├
#            └───┘      └───┘└───┘└╥┘
#  c18: 1/═════════════════════════╩═
#                                  0

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'1': 1024}

# %%
circuit = QuantumCircuit(q,c)
circuit.x(q[0])
circuit.u3(pi/2, pi/4, pi/7, q[1])
circuit.h(q[2])
circuit.cswap(q[2],q[0], q[1])
circuit.h(q[2])
circuit.x(q[2])
circuit.measure(q[2],c)
circuit.draw()
# Out:
# /tmp/ipykernel_159080/3034130458.py:3: DeprecationWarning: The QuantumCircuit.u3 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use QuantumCircuit.u instead, which acts identically. Alternatively, you can decompose u3 in terms of QuantumCircuit.p and QuantumCircuit.sx: u3(ϴ,φ,λ) = p(φ+π) sx p(ϴ+π) sx p(λ) (2 pulses on hardware).
#   circuit.u3(pi/2, pi/4, pi/7, q[1])
#                ┌───┐
# q314_0: ───────┤ X ├────────X──────────────
#         ┌──────┴───┴──────┐ │
# q314_1: ┤ U3(π/2,π/4,π/7) ├─X──────────────
#         └──────┬───┬──────┘ │ ┌───┐┌───┐┌─┐
# q314_2: ───────┤ H ├────────■─┤ H ├┤ X ├┤M├
#                └───┘          └───┘└───┘└╥┘
#  c18: 1/═════════════════════════════════╩═
#                                          0

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'0': 256, '1': 768}

# %%
circuit = QuantumCircuit(q,c)
circuit.rx(pi/2, q[0])
circuit.rz(pi/2, q[1])
circuit.h(q[2])
circuit.cswap(q[2],q[0], q[1])
circuit.h(q[2])
circuit.x(q[2])
circuit.measure(q[2],c)
circuit.draw()
# Out:
#         ┌─────────┐
# q314_0: ┤ Rx(π/2) ├─X──────────────
#         ├─────────┤ │
# q314_1: ┤ Rz(π/2) ├─X──────────────
#         └──┬───┬──┘ │ ┌───┐┌───┐┌─┐
# q314_2: ───┤ H ├────■─┤ H ├┤ X ├┤M├
#            └───┘      └───┘└───┘└╥┘
#  c18: 1/═════════════════════════╩═
#                                  0

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'1': 761, '0': 263}

# %% [markdown]
# # Question 5

# %% [markdown]
# Question5-(a)

# %%
def _set_qubits(n):
    global circuit
    q = QuantumRegister(n)
    c = ClassicalRegister(n)
    circuit = qiskit.QuantumCircuit(q, c)
    circuit.h(q) # Apply Hadamard gate to qubits
    circuit.measure(q,c) # Collapses qubit to either 1 or 0 w/ equal prob.
    simulator = Aer.get_backend('qasm_simulator')
    job = execute(circuit, simulator, shots = 102400)
    result = job.result()
    counts = result.get_counts()
    print(counts)
    return plot_histogram(counts)

_set_qubits(3)
# Out:
# {'110': 12886, '100': 12817, '101': 12920, '001': 12902, '010': 12463, '000': 12799, '111': 12725, '011': 12888}

# %% [markdown]
# Question5-(b)

# %%
def _set_qubits(n):
    global circuit
    q = QuantumRegister(n)
    c = ClassicalRegister(n)
    circuit = qiskit.QuantumCircuit(q, c)
    circuit.h(q) # Apply Hadamard gate to qubits
    circuit.measure(q,c) # Collapses qubit to either 1 or 0 w/ equal prob.
    simulator = Aer.get_backend('qasm_simulator')
    job = execute(circuit, simulator, shots = 102400)
    result = job.result()
    counts = result.get_counts()
    print(counts)
    return plot_histogram(counts)

_set_qubits(3)
circuit.draw()
# Out:
# {'100': 12782, '001': 12715, '110': 12785, '101': 13024, '010': 12873, '000': 12648, '011': 13073, '111': 12500}
#           ┌───┐┌─┐
# q11628_0: ┤ H ├┤M├──────
#           ├───┤└╥┘┌─┐
# q11628_1: ┤ H ├─╫─┤M├───
#           ├───┤ ║ └╥┘┌─┐
# q11628_2: ┤ H ├─╫──╫─┤M├
#           └───┘ ║  ║ └╥┘
#  c2269: 3/══════╩══╩══╩═
#                 0  1  2

# %%
api_token = "b9a340c91ff05ac9f5cc36eb235cf52f9a5acf42339f8f3e70fa92e35848927ea8765aa1815c15126fbbe2340d68a272953299fdfe59899a2e27913ae7685e4d"
IBMQ.save_account(api_token)
# Out:
# configrc.store_credentials:WARNING:2022-09-21 17:30:04,764: Credentials already present. Set overwrite=True to overwrite.

# %%
from qiskit.tools.monitor import job_monitor
IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
qcomp = provider.get_backend('ibmq_manila')
job = execute(circuit, backend=qcomp, shots=1000)
job_monitor(job)
# Out:
# ibmqfactory.load_account:WARNING:2022-09-21 17:30:07,512: Credentials are already in use. The existing account in the session will be replaced.
# Job Status: job has successfully run

# %%
result = job.result()
counts = result.get_counts(circuit)
plot_histogram(counts)

# %% [markdown]
# Bonus1

# %%
def _set_qubits_2(n, shot):
    global circuit
    q = QuantumRegister(n)
    c = ClassicalRegister(n)
    circuit = qiskit.QuantumCircuit(q, c)
    circuit.h(q) # Apply Hadamard gate to qubits
    circuit.measure(q,c) # Collapses qubit to either 1 or 0 w/ equal prob.
    simulator = Aer.get_backend('qasm_simulator')
    job = execute(circuit, simulator, shots=shot)
    result = job.result()
    counts = result.get_counts()
    return max(counts, key=counts.get)
l = []
for i in range(1024):
        l.append(str(int(_set_qubits_2(3, 1),2)))
with open("./output_bonus_1_3bit.txt", "w") as out:
    for i in range(len(l)):
        out.write(l[i] + "\n")
l = []
for i in range(1024):
        l.append(str(int(_set_qubits_2(2, 1),2)))
with open("./output_bonus_1_2bit.txt", "w") as out:
    for i in range(len(l)):
        out.write(l[i] + "\n")

# %% [markdown]
# Bonus2
